# %% [markdown]
# # Introduction to Statistical Inference and review of random samples
# ## Statistical Inference
# - In Statistical inference we
#     - use a *sample* to learn about a *population*
#         - where sample has properties of a random sample $X_1,X_2,...,X_n$
#         - and where population can be descributed by a probability distribution
#     - aka. use *data* to learn about a *parameter* (of a population)
# - The formal process of this *learning* uses probabilistic models
# - We assume that **a population of interest can be described by a probability distribution**. For example:
#     - Life time of a Christmas light series follows the $Expo(\theta)$
#     - The diastolic Blood Pressure of all US adults can be modeled as $N(\mu,\sigma^2)$
#     - Arrivals of customers can be modeled as Poisson process with unknown arrival rate $\lambda$
# - We *model* data as realizations of random variables that have the population distribution, $f(x|\theta)$
#     - $f(x|\theta)$ depends on an unknown parameter $\theta$
# - Given the data we have observed (and the model we chose for the population) what can we say about the unknown parameters $\theta$?
#     - i.e. we observe random variables
#
#         $X_i\sim f(x|\theta),\,i=1,...,n$
#
#         where $n$ is sample size, and want to draw probabilistic conclusions about $\theta$.
#     - This is **parameter estimation**
# - Once we have a good estimate of $\theta$ we may want to use $f(x|\theta)$ to predict new observations from the population
#     - This is **prediction**
#         - predict $X_?$ which has been not observed so far.

# %%
from IPython.display import Image

Image(filename="Images\\5-1-1.png")

# %% [markdown]
# ### Example: Flower seeds
# - A storage bin contains 10 million flower seeds each of which either produce white or red flowers.
# - How many (or what percentage) will produce white flowers?
# - To answer that question we take a sample of 100 seeds, plant them and observe the color or the flowers they produce

# %%
from IPython.display import Image

Image(filename="Images\\5-1-2.png")

# %% [markdown]
# - Population:
#     - $p=$ proportion of seeds that give white flowers
#     - $1-p=$ proportion of seeds that give red flowers
#
#     The parameter $p$ is unknown, a constant number (not a random variable)
# - Sample: $n$ seeds are selected and planted
#
#     $X_i =
#     \begin{cases}
#     1 & \text{if seed } i \text{ produces a white flower} \\
#     0 & \text{otherwise}
#     \end{cases}, \quad i = 1, 2, \ldots, n.$
#
#     and the distribution of $X_i\sim Bernoulli(p)$
# - Random variables
#
#     $X_i =
#     \begin{cases}
#     1 & \text{if seed } i \text{ produces a white flower} \\
#     0 & \text{otherwise}
#     \end{cases}, \quad i = 1, 2, \ldots, n.$
# - The stastistic $Y=\sum_{i=1}^nX_i\sim Binomial(n,p)$
# - Data=realization of random variables
#
#     $x_i =
#     \begin{cases}
#     1 & \text{if seed } i \text{ produces a white flower} \\
#     0 & \text{otherwise}
#     \end{cases}, \quad i = 1, 2, \ldots, n.$
#
#     or $y=$ total number of seeds that produced a white flower
# - Say we got 89 white flowers out of the $n=100$ seeds we planted. What does that tell us about $p$?
# - Common sense estimate of $p$ (**Points estimation**):
#
# $$\hat{p}=\frac{y}{n}=\frac{89}{100}=0.89$$
#
# - How sure am I about this number?
#     - Uncertainty bounds on the estimate $\to$ **Interval estimation**
#     - How confident am I that $p<0.9\to$ **Hypothesis testing**
# - A customer gets a random sample of 300 new seeds. Based on my data what can I tell them about how many white flowers they can expect? $\to$ **Prediction**

# %% [markdown]
# ## Random samples – Review
# ### Key topics
# - Random sample
# - Statistic, Order Statistic
# - Sampling distribution
# - Sampling distributions of the sample mean $\bar{X}$ and the sample variance $S^2$
#     - Special case: Normal random sample
# - The $t_p$ and $F_{p,q}$ distributions

# %% [markdown]
# ### Definition of a random sample
# #### Random sample
# Random variables $X_1,...,X_n$ are called a random sample of size $n$ from the population $f(x|\theta)$
#
# - If $X_1,...,X_n$ are independent and identically distributed (iid) random variables with pdf or pmf $f(x)$
#
#     - i.i.d $f(x)=$ random sample from $f(x)$

# %% [markdown]
# ### Definition of a statistic
# #### A statistic
# Let
# - $X_1,...,X_n$ be a random sample of size $n$
# - $T(X_1,...,X_n)$ be a real-valued (or vector-valued) function with domain that includes the sample space of ($X_1,...,X_n$)
#
# then
# - The random variable (or random vector) $Y=T(X_1,...,X_n)$ is called a **Statistic**.
# - The probability distribution of $Y$ is called the **Sampling Distribution of $Y$**
# - In short: A statistic is a function of a random sample.
# - Note: Cannot be a function of a parameter.

# %% [markdown]
# #### Commonly seen statistics
# - Sample mean:
# $$\overline{X}=\frac{1}{n}(X_1+\cdots+X_n)=\frac{1}{n}\sum_{i=1}^nX_i$$
# - Sample variance:
# $$S^2=\frac{1}{n-1}\sum_{i=1}^n(X_i-\overline{X})^2$$
# - Sample standard deviation:
# $$S=\sqrt{S^2}$$
#
# The random variables $\bar{X},S^2$ and $S$ all have a sampling distribution.

# %% [markdown]
# #### Moments of sums
#
# **Lemma:**
#
# Let $X_1,...,X_n$ be a random sample of size $n$ from a population and let $g(x)$ be a function such that $E(g(X_1))$ and $Var(g(X_1))$ exist. Then
#
# $\mathbb{E}\left(\sum_{i=1}^ng(X_i)\right)=n\mathbb{E}\left(g(X_1)\right)$
#
# $\mathrm{Var}\left(\sum_{i=1}^{n}g(X_{i})\right)=n\mathrm{Var}\left(g(X_{1})\right)$
#
# Say $E(X_i)=\mu,Var(X_i)=\sigma^2$, then $E(\sum_{i=1}^ng(X_i))=n\mu, Var(\sum_{i=1}^ng(X_i))=n\sigma^2$

# %% [markdown]
# #### Moments of some common statistics
# **Theorem**
#
# Let $X_1,...,X_n$ be a random sample of size $n$ from a population with mean $\mu$ and variance $\sigma^2<\infty$
# 1. $E(bar{X})=\mu$
# 2. $Var(\bar{X})=\frac{\sigma^2}{n}$
# 3. $E(S^2)=\sigma^2$
#
# Useful fact: For any numbers $x_1,...,x_n$, we have
# $\sum_{i=1}^n(x_i-\overline{x})^2=\sum_{i=1}^nx_i^2-n\overline{x}^2$
# - where $\bar{x}=\frac{1}{n}\sum_{i=1}^nx_i$

# %% [markdown]
# #### Sampling from the Normal Distribution
# Theorem 5.3.1: Distribution of $\bar{X}$ and $S^2$
#
# Let $X_1,...,X_n$ be a random sample from $N(\mu,\sigma^2)$ and let
# - $\bar{X}=\frac{1}{n}\sum_{i=1}^nX_i$
# - $S^2=\frac{1}{n-1}\sum_{i=1}^n(X_i-\overline{X})^2$
#
# then
# - $\bar{X}$ and $S^2$ are independent
# - $\bar{X}\sim N(\mu,\frac{\sigma^2}{n})$
# - $\frac{(n-1)S^2}{\sigma^2}\sim\chi^2_{n-1}$

# %% [markdown]
# ### The student’s $t$ distribution
# **Definition: The $t$ distribution**
#
# Let $U\sim N(0,1)$ and $V\sim\chi^2_{p}$, $U$ and $V$ are independent. The distribution of $T=\frac{U}{\sqrt{V/p}}$ is called the $t$ distribution with $p$ degrees of freedom, or $t_p$
#
# **The T statistic**
#
# Let $X_1,X_2,...,X_n$ be a random sample from a normal distribution with mean $\mu$ and variance $\sigma^2$. Then
#
# $T=\frac{\bar{X}-\mu}{S-\sqrt{n}}\sim t_{n-1}$

# %% [markdown]
# ### Snedecor’s $F$ distribution
# **Def: $F_{p,q}$-distribution**
#
# Let $X\sim\chi_p^2$ and $Y\sim\chi_q^2$ be independent random variables. The distribution of $U=\frac{X/p}{Y/q}$ is called the $F$ distribution with $p$ and $q$ degrees of freedom
#
# **The $F$ statistic**
# - Let $X_1,X_2,...,X_n$ be a random sample from $N(\mu_X,\sigma_X^2)$
# - Let $Y_1,Y_2,...,Y_m$ be a random sample from $N(\mu_Y,\sigma_Y^2)$. Then
#     - $F=\frac{S_X^2/\sigma_X^2}{S_Y^2/\sigma_Y^2}\sim F_{n-1,m-1}$

# %% [markdown]
# ### Order Statistics
# Let $X_1,X_2,...,X_n$ be a random sample. The statistics
# - $X_{(1)}=min{X_1,X_2,...,X_n}$
# - $X_{(2)}=\text{second smallest}{X_1,X_2,...,X_n}$
# - $...$
# - $X_{(n-1)}=\text{second largest}{X_1,X_2,...,X_n}$
# - $X_{(n)}=max{X_1,X_2,...,X_n}$
#
# are called order statistics.
#
# Examples:
# - Weight of smallest kitten in a litter
# - Highest score on an exam
# W
# e want to find the (sampling) distributions of order statistics

# %% [markdown]
# ### Distributions of order statistics
# **Theorem: distribution of order statistics**
#
# Let $X_1,X_2,...,X_n$ be a random sample from a **continuous distribution**, with pdf $f(x)$ and cdf $F(x)$.
#
# Then the cdf and pdf of the $j$-th order statistic $X_{(j)}$ are
#
# $\begin{aligned}
#  & F_{(j)}(x)=\sum_{k=j}^n\binom{n}{k}F(x)^k(1-F(x))^{n-k} \\
#  & f_{(j)}(x)=\frac{n!}{(j-1)!(n-j)!}f(x)F(x)^{j-1}\left(1-F(x)\right)^{n-j}
# \end{aligned}$
#
# ### Reference
#
# [1] [Statistical inference](https://github.com/Thomson-Cui/Theoretical-Statistics-I/blob/main/Chapter%205-1%2C2%20Random%20Samples.ipynb)
#
# [2] [Random Sample](https://github.com/Thomson-Cui/Theoretical-Statistics-I/blob/main/Chapter%205-3%20Random%20sample%20from%20a%20normal%20population.ipynb)
#
# [3] [Order Statistics](https://github.com/Thomson-Cui/Theoretical-Statistics-I/blob/main/Chapter%205-4%20Order%20Statistics.ipynb)
